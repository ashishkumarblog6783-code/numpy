# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/numpy/blob/main/7pd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data={
    'student':["palak","nisha","rahul","juga","tina","meena"],
    'rank':[1,2,3,4,5,6],
    'marks':[90,76,99,62,89,76]

}
df=pd.DataFrame(data)
print(df)
print(df[['rank','marks']])
# Out:
#   student  rank  marks
# 0   palak     1     90
# 1   nisha     2     76
# 2   rahul     3     99
# 3    juga     4     62
# 4    tina     5     89
# 5   meena     6     76
#    rank  marks
# 0     1     90
# 1     2     76
# 2     3     99
# 3     4     62
# 4     5     89
# 5     6     76

# %%
import pandas as pd

data={
    'id':["s01","s02","s03","s04","s05","s06"],
    'student':["palak","nisha","rahul","juga","tina","meena"],
    'rank':[1,2,3,4,5,6],
    'marks':[90,76,99,62,89,76],
    'address':["east","west","north","south","siuth-south","east north"]

}
df=pd.DataFrame(data)
print(df)
print(df[df.columns[2:5]])
# Out:
#     id student  rank  marks      address
# 0  s01   palak     1     90         east
# 1  s02   nisha     2     76         west
# 2  s03   rahul     3     99        north
# 3  s04    juga     4     62        south
# 4  s05    tina     5     89  siuth-south
# 5  s06   meena     6     76   east north
#    rank  marks      address
# 0     1     90         east
# 1     2     76         west
# 2     3     99        north
# 3     4     62        south
# 4     5     89  siuth-south
# 5     6     76   east north
