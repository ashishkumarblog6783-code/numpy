# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/numpy/blob/main/9pd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data={
    'id':["s01","s02","s03","s04","s05"],
    'student':["sihu","lojei","gghd","gini","pmi"],
    'rank':[2,3,4,5,6],
    'marks':[67,78,55,34,90]

}
dataFrame=pd.DataFrame(data)
print(dataFrame)

res=dataFrame.drop("marks",axis='columns')
print(res)
# Out:
#     id student  rank  marks
# 0  s01    sihu     2     67
# 1  s02   lojei     3     78
# 2  s03    gghd     4     55
# 3  s04    gini     5     34
# 4  s05     pmi     6     90
#     id student  rank
# 0  s01    sihu     2
# 1  s02   lojei     3
# 2  s03    gghd     4
# 3  s04    gini     5
# 4  s05     pmi     6

# %%
import pandas as pd
data={
    'id':["s01","s02","s03","s04","s05"],
    'student':["sihu","lojei","gghd","gini","pmi"],
    'rank':[2,3,4,5,6],
    'marks':[67,78,55,34,90]

}
dataFrame=pd.DataFrame(data)
print(dataFrame)

res=dataFrame.drop(2,axis='index')
print(res)
# Out:
#     id student  rank  marks
# 0  s01    sihu     2     67
# 1  s02   lojei     3     78
# 2  s03    gghd     4     55
# 3  s04    gini     5     34
# 4  s05     pmi     6     90
#     id student  rank  marks
# 0  s01    sihu     2     67
# 1  s02   lojei     3     78
# 3  s04    gini     5     34
# 4  s05     pmi     6     90
