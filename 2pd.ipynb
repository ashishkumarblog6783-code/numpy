# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/numpy/blob/main/2pd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data={
    'student':["ajir","togo","arohi",'palak',"priyanka"],
    'rank':[1,3,5,6,3],
    'marks':[67,89,67,90,45]


}
df=pd.DataFrame(data,index=['row1','row2','row3','row4','row5'])
print("student record",df)
print("\ndatatype",df.dtypes)
# Out:
# student record        student  rank  marks
# row1      ajir     1     67
# row2      togo     3     89
# row3     arohi     5     67
# row4     palak     6     90
# row5  priyanka     3     45
#
# datatype student    object
# rank        int64
# marks       int64
# dtype: object

# %%
import pandas as pd
data={
    'student':["ajir","togo","arohi",'palak',"priyanka"],
    'rank':[1,3,5,6,3],
    'marks':[67,89,67,90,45]


}
df=pd.DataFrame(data,index=['row1','row2','row3','row4','row5'])
print("student record",df)


print("\ndatadimension",df.ndim)
# Out:
# student record        student  rank  marks
# row1      ajir     1     67
# row2      togo     3     89
# row3     arohi     5     67
# row4     palak     6     90
# row5  priyanka     3     45
#
# datadimension 2

# %%
import pandas as pd
data={
    'student':["ajir","togo","arohi",'palak',"priyanka"],
    'rank':[1,3,5,6,3],
    'marks':[67,89,67,90,45]


}
df=pd.DataFrame(data,index=['row1','row2','row3','row4','row5'])
print("student record",df)
print("\ndatasize",df.size)
# Out:
# student record        student  rank  marks
# row1      ajir     1     67
# row2      togo     3     89
# row3     arohi     5     67
# row4     palak     6     90
# row5  priyanka     3     45
#
# datasize 15

# %%
import pandas as pd
data={
    'student':["ajir","togo","arohi",'palak',"priyanka"],
    'rank':[1,3,5,6,3],
    'marks':[67,89,67,90,45]


}
df=pd.DataFrame(data,index=['row1','row2','row3','row4','row5'])
print("student record",df)
print("\ndatatype",df.dtypes)

# %%
import pandas as pd
data={
    'student':["ajir","togo","arohi",'palak',"priyanka"],
    'rank':[1,3,5,6,3],
    'marks':[67,89,67,90,45]


}
df=pd.DataFrame(data,index=['row1','row2','row3','row4','row5'])
print("student record",df)
print("\ndatatype",df.dtypes)
print(df.T)
# Out:
# student record        student  rank  marks
# row1      ajir     1     67
# row2      togo     3     89
# row3     arohi     5     67
# row4     palak     6     90
# row5  priyanka     3     45
#
# datatype student    object
# rank        int64
# marks       int64
# dtype: object
#          row1  row2   row3   row4      row5
# student  ajir  togo  arohi  palak  priyanka
# rank        1     3      5      6         3
# marks      67    89     67     90        45

# %%
import pandas as pd
data={
    'student':["ajir","togo","arohi",'palak',"priyanka"],
    'rank':[1,3,5,6,3],
    'marks':[67,89,67,90,45]


}
df=pd.DataFrame(data,index=['row1','row2','row3','row4','row5'])
print("student record",df)
print("\ndatatype",df.dtypes)
print(df.head())
# Out:
# student record        student  rank  marks
# row1      ajir     1     67
# row2      togo     3     89
# row3     arohi     5     67
# row4     palak     6     90
# row5  priyanka     3     45
#
# datatype student    object
# rank        int64
# marks       int64
# dtype: object
#        student  rank  marks
# row1      ajir     1     67
# row2      togo     3     89
# row3     arohi     5     67
# row4     palak     6     90
# row5  priyanka     3     45

# %% [markdown]
# last 5 row

# %%
import pandas as pd
data={
    'student':["ajir","togo","arohi",'palak',"priyanka"],
    'rank':[1,3,5,6,3],
    'marks':[67,89,67,90,45]


}
df=pd.DataFrame(data,index=['row1','row2','row3','row4','row5'])
print("student record",df)
print(df.tail())
# Out:
# student record        student  rank  marks
# row1      ajir     1     67
# row2      togo     3     89
# row3     arohi     5     67
# row4     palak     6     90
# row5  priyanka     3     45
#        student  rank  marks
# row1      ajir     1     67
# row2      togo     3     89
# row3     arohi     5     67
# row4     palak     6     90
# row5  priyanka     3     45
