# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/numpy/blob/main/3pd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data1={
    'id':["01","02","03","04","05"],
    'student':["anita","john","poki","loki","koko"],
    "roll":[101,203,645,444,77]
}

data2={
    'rank':[1,4,5,6,7],
    'marks':[55,87,34,90,99]
}
dataFrame1=pd.DataFrame(data1)
print("dataframe1",dataFrame1)
dataFrame2=pd.DataFrame(data2)
print("dataframe2",dataFrame2)


resDF=dataFrame1.join(dataFrame2)
print("joining two data frames",resDF)
# Out:
# dataframe1    id student  roll
# 0  01   anita   101
# 1  02    john   203
# 2  03    poki   645
# 3  04    loki   444
# 4  05    koko    77
# dataframe2    rank  marks
# 0     1     55
# 1     4     87
# 2     5     34
# 3     6     90
# 4     7     99
# joining two data frames    id student  roll  rank  marks
# 0  01   anita   101     1     55
# 1  02    john   203     4     87
# 2  03    poki   645     5     34
# 3  04    loki   444     6     90
# 4  05    koko    77     7     99

# %% [markdown]
# CONCATENATE

# %%
import pandas as pd

data1={
    'id':["01","02","03","04","05"],
    'student':["anita","john","poki","loki","koko"],
    "roll":[101,203,645,444,77]
}

data2={
    'rank':[1,4,5,6,7],
    'marks':[55,87,34,90,99]
}
dataFrame1=pd.DataFrame(data1)
print("dataframe1",dataFrame1)
dataFrame2=pd.DataFrame(data2)
print("dataframe2",dataFrame2)

concatenate=pd.concat([dataFrame1,dataFrame2])
print("concatenating two data frames",concatenate)
# Out:
# dataframe1    id student  roll
# 0  01   anita   101
# 1  02    john   203
# 2  03    poki   645
# 3  04    loki   444
# 4  05    koko    77
# dataframe2    rank  marks
# 0     1     55
# 1     4     87
# 2     5     34
# 3     6     90
# 4     7     99
# concatenating two data frames     id student   roll  rank  marks
# 0   01   anita  101.0   NaN    NaN
# 1   02    john  203.0   NaN    NaN
# 2   03    poki  645.0   NaN    NaN
# 3   04    loki  444.0   NaN    NaN
# 4   05    koko   77.0   NaN    NaN
# 0  NaN     NaN    NaN   1.0   55.0
# 1  NaN     NaN    NaN   4.0   87.0
# 2  NaN     NaN    NaN   5.0   34.0
# 3  NaN     NaN    NaN   6.0   90.0
# 4  NaN     NaN    NaN   7.0   99.0
