# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/numpy/blob/main/8pd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
 data={
     'id':["s01","s02","s03","s04","s05"],
     'student':["poki","dora","heem","ninja","jagu"],
     'rank':[56,78,90,76,78],
     'marks':[676,87,8784,987,90]
 }

 dataFrame=pd.DataFrame(data)
 print(dataFrame)

 dataFrame.insert(2,"roll",[101,203,405,607,55])
 print(dataFrame)
# Out:
#     id student  rank  marks
# 0  s01    poki    56    676
# 1  s02    dora    78     87
# 2  s03    heem    90   8784
# 3  s04   ninja    76    987
# 4  s05    jagu    78     90
#     id student  roll  rank  marks
# 0  s01    poki   101    56    676
# 1  s02    dora   203    78     87
# 2  s03    heem   405    90   8784
# 3  s04   ninja   607    76    987
# 4  s05    jagu    55    78     90

# %%
import pandas as pd
data={
     'id':["s01","s02","s03","s04","s05"],
     'student':["poki","dora","heem","ninja","jagu"],
     'rank':[56,78,90,76,78],
     'marks':[676,87,8784,987,90]
 }

dataFrame=pd.DataFrame(data)
print(dataFrame)

res=dataFrame.assign(Roll=[101,203,406,789,78])
print(res)
# Out:
#     id student  rank  marks
# 0  s01    poki    56    676
# 1  s02    dora    78     87
# 2  s03    heem    90   8784
# 3  s04   ninja    76    987
# 4  s05    jagu    78     90
#     id student  rank  marks  Roll
# 0  s01    poki    56    676   101
# 1  s02    dora    78     87   203
# 2  s03    heem    90   8784   406
# 3  s04   ninja    76    987   789
# 4  s05    jagu    78     90    78
