# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/numpy/blob/main/4pd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# series

# %%
import pandas as pd
data=[10,20,30,40,50]

s=pd.Series(data)
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# ACCESS VALUE FROM SERIES

# %%
import pandas as pd
data=[10,20,30,40,50]

s=pd.Series(data)
print(s)
print(s[2])
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# 30

# %% [markdown]
# name index

# %%
import pandas as pd
data=[10,20,30,40,50]

s=pd.Series(data,index=["rowa","rowb","rowc","rowd","rowe"])
print(s)
# Out:
# rowa    10
# rowb    20
# rowc    30
# rowd    40
# rowe    50
# dtype: int64

# %% [markdown]
# access any value

# %%
import pandas as pd
data=[10,20,30,40,50]

s=pd.Series(data,index=["rowa","rowb","rowc","rowd","rowe"])
print(s)
print(" ",s["rowd"])
# Out:
# rowa    10
# rowb    20
# rowc    30
# rowd    40
# rowe    50
# dtype: int64
#   40

# %%
import pandas as pd
data=[10,20,30,40,50]

s=pd.Series(data)
print(s)
print(s[2],s.dtype)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# 30 int64

# %%
import pandas as pd
data=[10,20,30,40,50]

s=pd.Series(data)
print(s)
print(s[2])
print(s.ndim)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# 30
# 1

# %%
import pandas as pd
data=[10,20,30,40,50]

s=pd.Series(data)
print(s)
print(s[2])
print(s.size)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# 30
# 5

# %%
import pandas as pd
import numpy as np
data=[10,20,30,40,50,np.nan]

s=pd.Series(data)
print(s)
print(s[2])
print(s.hasnans)
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# 3    40.0
# 4    50.0
# 5     NaN
# dtype: float64
# 30.0
# True

# %%
import pandas as pd
data=[10,20,30,40,50]

s=pd.Series(data)
print(s)
print(s[2])
print(s.tail())
print(s.head(2))
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# 30
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# 0    10
# 1    20
# dtype: int64

# %%
import pandas as pd
data=[10,20,30,40,50]

s=pd.Series(data)
print(s)
print(s[2])
print(s.info())
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# 30
# <class 'pandas.core.series.Series'>
# RangeIndex: 5 entries, 0 to 4
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 5 non-null      int64
# dtypes: int64(1)
# memory usage: 172.0 bytes
# None
