# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/numpy/blob/main/7ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[4,5,6,7]
plt.subplot(2,3,4)
plt.plot(x,y,color="r")
plt.subplot(2,3,5)
plt.pie([1])
x1=[10,20,30,40]

x2=["a","b","c","d"]
plt.subplot(2,2,1)
y2=[23,45,67,89]
plt.bar(x2,y2)

plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fc9f7209a90>,
# ...
#  [Text(1.0461621649530053, 0.3399187029582827, ''),
#   Text(0.33991865722907993, 1.0461621798113232, ''),
#   Text(-1.046162235191088, 0.33991848678762215, ''),
#   Text(0.33991884014588697, -1.0461621203780394, '')])
