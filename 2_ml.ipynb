# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/numpy/blob/main/2_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
x=np.random.randint(10,60,(50))
print(x)
# Out:
# [58 20 49 22 27 34 48 59 58 32 39 30 13 48 53 41 20 28 40 33 53 21 13 10
#  25 35 48 41 54 46 26 11 43 31 20 18 56 28 17 39 29 59 21 49 14 43 59 19
#  43 57]

# %%
np=[58 ,20, 49, 22, 27, 34, 48, 59 ,58 ,32 ,39 ,30 ,13 ,48 ,53 ,41 ,20 ,28 ,40 ,33 ,53 ,21 ,13 ,10
 ,25 ,35 ,48 ,41 ,54 ,46 ,26 ,11 ,43 ,31 ,20 ,18 ,56 ,28 ,17 ,39 ,29 ,59 ,21 ,49 ,14 ,43 ,59 ,19
 ,43 ,57]
plt.hist(np,color="pink",edgecolor="black",bins=10,cumulative=-1,bottom=10,orientation="horizontal")
plt.xlabel("pogo")
plt.legend()
plt.ylabel("hungama")
plt.title("cn")
plt.show()
# Out:
# /tmp/ipython-input-438/3780907637.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
